# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 2000
Q_0 = np.diag(np.array([(n-N)/N for n in range(N)]+ [2*n/N for n in range(N//2)], dtype=complex))
N_x = Q_0.shape[0]

# %%
L_0 = np.zeros(shape=(N_x, N_x), dtype=complex)
for i in range(N_x):
    for j in range(N_x):
        if i != j:
            L_0[i,j] = 1j/(Q_0[i,i] - Q_0[j,j])

# %%
def L(t): return Q_0 + t*L_0

# %%
def Q(t): return np.sort(np.linalg.eigvals(L(t)).real)

# %%
N_bins = N//50
delta_bins = 2/N_bins
bins = np.array([2*n/N_bins -1 for n in range(N_bins)])

# %%
def Weyl(t):
    positions = Q(t)
    hist = np.zeros(N_bins)
    for i in range(N_bins):
        hist[i] = np.sum(positions < bins[i])
    return hist

# %%
def density(t):
    W = Weyl(t)
    return (W[1:] - W[:-1])/delta_bins

# %%
plt.plot(density(0)/N)
#plt.show()
plt.savefig("mixing-plots/00.png")

# %%
plt.plot(density(1e-5)/N)
#plt.show()
plt.savefig("mixing-plots/01.png")

# %%
plt.plot(density(2e-5)/N)
#plt.show()

plt.savefig("mixing-plots/02.png")

# %%
plt.plot(density(3e-5)/N)
#plt.show()

plt.savefig("mixing-plots/03.png")

# %%
plt.plot(density(4e-5)/N)
#plt.show()
plt.savefig("mixing-plots/04.png")

# %%
plt.plot(density(5e-5)/N)
#plt.show()
plt.savefig("mixing-plots/05.png")

# %%
plt.plot(density(6e-5)/N)
#plt.show()
plt.savefig("mixing-plots/06.png")

# %%
plt.plot(density(7e-5)/N)
#plt.show()
plt.savefig("mixing-plots/07.png")

# %%
plt.plot(density(8e-5)/N)
#plt.show()
plt.savefig("mixing-plots/08.png")

# %%
plt.plot(density(9e-5)/N)
#plt.show()
plt.savefig("mixing-plots/09.png")

# %%
plt.plot(density(10e-5)/N)
#plt.show()
plt.savefig("mixing-plots/10.png")

# %%
plt.plot(density(11e-5)/N)
#plt.show()
plt.savefig("mixing-plots/11.png")

# %%
plt.plot(density(12e-5)/N)
#plt.show()
plt.savefig("mixing-plots/12.png")

# %%
plt.plot(density(13e-5)/N)
#plt.show()
plt.savefig("mixing-plots/13.png")

# %%
plt.plot(density(14e-5)/N)
#plt.show()
plt.savefig("mixing-plots/14.png")

# %%
plt.plot(density(15e-5)/N)
#plt.show()
plt.savefig("mixing-plots/15.png")

# %%
plt.plot(density(16e-5)/N)
#plt.show()
plt.savefig("mixing-plots/16.png")

# %%
plt.plot(density(17e-5)/N)
#plt.show()
plt.savefig("mixing-plots/17.png")

# %%
plt.plot(density(18e-5)/N)
#plt.show()
plt.savefig("mixing-plots/18.png")

# %%
plt.plot(density(19e-5)/N)
#plt.show()
plt.savefig("mixing-plots/19.png")

# %%
plt.plot(density(20e-5)/N)
#plt.show()
plt.savefig("mixing-plots/20.png")
